# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.33.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
import random
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2Model, GPT2Config

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
A = 5 # number of actions
N = 80000 # number of offline samples
n = 500
eps = 1e-10

# %%
def generate_B(A=5, N=80000, n=500):
    dsets, v_dsets, actions, coefficients, opt_idxs = [], [], [], [], []
    for _ in range(N):
        p_1 = np.random.dirichlet(np.ones(A))
        p_2 = np.zeros(A)
        idx = np.random.choice(A)
        p_2[idx] = 1
        w = (np.random.choice(10) + 1) / 10
        p = (1 - w) * p_1 + w * p_2

        a = np.random.choice(A, n, p=p)
        actions.append(a)
        mu = np.random.rand(A)
        coefficients.append(np.exp(mu[a] - np.dot(p, mu)))
        r = np.random.normal(mu[a], 0.3)
        opt_a = np.argmax(mu)
        opt_idxs.append(np.full(n, opt_a))

        a_one_hot = np.zeros((n, A))
        a_one_hot[np.arange(n), a] = 1

        X = np.zeros((n, A + 3), np.float32)
        X[:, 0] = 1
        X[:, 1:A + 1] = a_one_hot
        X[:, -2] = 1
        X[:, -1] = r
        dsets.append(X)
    return dsets, actions, coefficients, opt_idxs

# %%
class BanditDataset(Dataset):
    def __init__(self, dsets, actions, coefficients, opt_idxs):
        self.dsets = dsets
        self.actions = actions
        self.coefficients = coefficients
        self.opt_idxs = opt_idxs

        self.first = np.zeros((1, A + 3), dtype=np.float32)
        self.first[0, 0] = 1

    def __len__(self):
        return len(self.dsets)

    def __getitem__(self, idx):
        p = np.random.permutation(n)
        sample_ds = self.dsets[idx]
        sample_ds = np.concatenate((self.first, sample_ds[p]))
        sample_actions = self.actions[idx][p]
        sample_coefficients = self.coefficients[idx][p]
        sample_opt_idxs = self.opt_idxs[idx][p]

        return sample_ds, sample_actions, sample_coefficients, sample_opt_idxs

# %%
class TransformerModel(nn.Module):
    def __init__(self, n_states, n_positions=501, n_embd=32, n_layer=4, n_head=4):
        super(TransformerModel, self).__init__()
        configuration = GPT2Config(
            n_positions=n_positions,
            n_embd=n_embd,
            n_layer=n_layer,
            n_head=n_head,
        )
        self.name = f"gpt2_embd={n_embd}_layer={n_layer}_head={n_head}"

        self.n_positions = n_positions
        self.n_dims = n_states
        self._read_in = nn.Linear(n_states + 3, n_embd)
        self._backbone = GPT2Model(configuration)
        self._read_out = nn.Linear(n_embd, 5)
        self._flatten = nn.Flatten(0, 1)

        for w in self._backbone.wpe.parameters():
            w.data.fill_(0)
        self._backbone.wpe.weight.requires_grad=False

    def forward(self, X):
        embeds = self._read_in(X)
        output = self._backbone(inputs_embeds=embeds).last_hidden_state
        logit = self._read_out(output)[:, :-1]
        logit = self._flatten(logit)
        return logit

# %%
def loss_fn(pred, a, c):
    ce_loss_fn = torch.nn.CrossEntropyLoss(reduction='none')
    return torch.mean(ce_loss_fn(pred, a) * c)

# %%
dsets_train, actions_train, coefficients_train, opt_idxs_train = generate_B(N=N)
dsets_val, actions_val, coefficients_val, opt_idxs_val = generate_B(N=N//4)

data_train = BanditDataset(dsets_train, actions_train, coefficients_train, opt_idxs_train)
data_val = BanditDataset(dsets_val, actions_val, coefficients_val, opt_idxs_val)

train_dataloader = DataLoader(data_train, batch_size=76)
val_dataloader = DataLoader(data_val, batch_size=76)

# %%
model = TransformerModel(n_states=5)
model.to(device)
model = nn.DataParallel(model)

# %%
optimizer = torch.optim.AdamW([param for param in model.parameters() if param.requires_grad == True])

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, a, c, opt) in enumerate(train_dataloader):
        X = X.to(device)
        pred = model(X)
        a = a.flatten().to(device)
        c = c.flatten().to(device)
        opt = opt.flatten().to(device)

        loss = loss_fn(pred, a, c)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        prob = F.softmax(pred, dim=1)

        opt_prob = prob[np.arange(prob.shape[0]), opt]
        next_prob = prob[np.arange(prob.shape[0]), a]
        comp = opt_prob - next_prob
        mse = torch.mean(torch.pow(comp, 2))

        if batch % 10 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            print("Comparison:", mse)

# %%
def test(dataloader, model, loss_fn):
    num_batches = len(dataloader)
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for X, a, c, opt in dataloader:
            X = X.to(device)
            pred = model(X)
            a = a.flatten().to(device)
            c = c.flatten().to(device)
            opt = opt.flatten().to(device)

            loss = loss_fn(pred, a, c)
            val_loss += loss.item()

    val_loss /= num_batches
    print(f"Val loss: {val_loss:>8f} \n")
    return val_loss

# %%
epochs = 100
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cur_val_loss = np.inf
cur_epoch = 1
cur_state_dict = None
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    cur_epoch = t + 1
    cur_state_dict = model.module.state_dict()
    test(val_dataloader, model, loss_fn)
    torch.save({
        'epoch': cur_epoch,
        'model_state_dict': cur_state_dict,
        }, 'transformer_model.pt')
    # if test(val_dataloader, model, loss_fn) < cur_val_loss:
    #     cur_epoch = t + 1
    #     cur_state_dict = model.module.state_dict()
    #     torch.save({
    #         'epoch': cur_epoch,
    #         'model_state_dict': cur_state_dict,
    #         }, 'transformer_model.pt')
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.924297  [   76/80000]
# Comparison: tensor(0.2727, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.986292  [  836/80000]
# Comparison: tensor(0.2665, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.016658  [ 1596/80000]
# Comparison: tensor(0.2226, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.000330  [ 2356/80000]
# Comparison: tensor(0.2538, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.883904  [ 3116/80000]
# Comparison: tensor(0.2538, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.994679  [ 3876/80000]
# Comparison: tensor(0.2279, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.959305  [ 4636/80000]
# Comparison: tensor(0.2444, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.877912  [ 5396/80000]
# Comparison: tensor(0.2803, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.905468  [ 6156/80000]
# Comparison: tensor(0.2756, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.939286  [ 6916/80000]
# Comparison: tensor(0.2658, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937931  [ 7676/80000]
# Comparison: tensor(0.2737, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.897713  [ 8436/80000]
# Comparison: tensor(0.2579, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.973067  [ 9196/80000]
# Comparison: tensor(0.2490, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.838948  [ 9956/80000]
# Comparison: tensor(0.3187, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.911658  [10716/80000]
# Comparison: tensor(0.2801, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.944927  [11476/80000]
# Comparison: tensor(0.2524, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920646  [12236/80000]
# Comparison: tensor(0.2594, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.889260  [12996/80000]
# Comparison: tensor(0.3003, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.877243  [13756/80000]
# Comparison: tensor(0.3182, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.971842  [14516/80000]
# Comparison: tensor(0.2495, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953853  [15276/80000]
# Comparison: tensor(0.2516, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.044953  [16036/80000]
# Comparison: tensor(0.1996, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.910765  [16796/80000]
# Comparison: tensor(0.2911, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.986958  [17556/80000]
# Comparison: tensor(0.2436, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.956838  [18316/80000]
# Comparison: tensor(0.2493, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.001202  [19076/80000]
# Comparison: tensor(0.2527, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.013129  [19836/80000]
# Comparison: tensor(0.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.959336  [20596/80000]
# Comparison: tensor(0.2288, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.923038  [21356/80000]
# Comparison: tensor(0.2604, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920602  [22116/80000]
# Comparison: tensor(0.3062, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.986468  [22876/80000]
# Comparison: tensor(0.2662, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.995363  [23636/80000]
# Comparison: tensor(0.2367, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929784  [24396/80000]
# Comparison: tensor(0.2947, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.054949  [25156/80000]
# Comparison: tensor(0.2029, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.994468  [25916/80000]
# Comparison: tensor(0.2133, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.897637  [26676/80000]
# Comparison: tensor(0.2843, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937304  [27436/80000]
# Comparison: tensor(0.2544, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.990346  [28196/80000]
# Comparison: tensor(0.2615, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.866656  [28956/80000]
# Comparison: tensor(0.2845, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.018358  [29716/80000]
# Comparison: tensor(0.2374, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954731  [30476/80000]
# Comparison: tensor(0.2706, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.904977  [31236/80000]
# Comparison: tensor(0.3132, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.960707  [31996/80000]
# Comparison: tensor(0.2440, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937367  [32756/80000]
# Comparison: tensor(0.3112, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.926057  [33516/80000]
# Comparison: tensor(0.2690, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.816588  [34276/80000]
# Comparison: tensor(0.3191, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.955863  [35036/80000]
# Comparison: tensor(0.2542, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.930430  [35796/80000]
# Comparison: tensor(0.2367, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.884557  [36556/80000]
# Comparison: tensor(0.2754, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937885  [37316/80000]
# Comparison: tensor(0.2853, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.915318  [38076/80000]
# Comparison: tensor(0.2709, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.890684  [38836/80000]
# Comparison: tensor(0.2956, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.966500  [39596/80000]
# Comparison: tensor(0.2454, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.862162  [40356/80000]
# Comparison: tensor(0.3374, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.944175  [41116/80000]
# Comparison: tensor(0.2683, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.867968  [41876/80000]
# Comparison: tensor(0.2849, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.890908  [42636/80000]
# Comparison: tensor(0.3050, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978107  [43396/80000]
# Comparison: tensor(0.2440, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.895118  [44156/80000]
# Comparison: tensor(0.3199, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.918516  [44916/80000]
# Comparison: tensor(0.2929, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.017495  [45676/80000]
# Comparison: tensor(0.2086, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.911328  [46436/80000]
# Comparison: tensor(0.3201, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.888523  [47196/80000]
# Comparison: tensor(0.2640, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.918314  [47956/80000]
# Comparison: tensor(0.3057, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.892584  [48716/80000]
# Comparison: tensor(0.2759, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.975111  [49476/80000]
# Comparison: tensor(0.2324, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.832701  [50236/80000]
# Comparison: tensor(0.3077, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.872012  [50996/80000]
# Comparison: tensor(0.3187, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.926033  [51756/80000]
# Comparison: tensor(0.2624, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.877487  [52516/80000]
# Comparison: tensor(0.3043, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914133  [53276/80000]
# Comparison: tensor(0.2955, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.969400  [54036/80000]
# Comparison: tensor(0.2556, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.909881  [54796/80000]
# Comparison: tensor(0.2686, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.000130  [55556/80000]
# Comparison: tensor(0.2517, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.909779  [56316/80000]
# Comparison: tensor(0.2752, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.997193  [57076/80000]
# Comparison: tensor(0.2469, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.054174  [57836/80000]
# Comparison: tensor(0.2076, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.895516  [58596/80000]
# Comparison: tensor(0.2673, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.967446  [59356/80000]
# Comparison: tensor(0.2771, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.919993  [60116/80000]
# Comparison: tensor(0.2839, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.980910  [60876/80000]
# Comparison: tensor(0.2497, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.938985  [61636/80000]
# Comparison: tensor(0.2529, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.956735  [62396/80000]
# Comparison: tensor(0.2595, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.928844  [63156/80000]
# Comparison: tensor(0.2685, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.951356  [63916/80000]
# Comparison: tensor(0.2379, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.987858  [64676/80000]
# Comparison: tensor(0.2198, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.832023  [65436/80000]
# Comparison: tensor(0.3251, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.963156  [66196/80000]
# Comparison: tensor(0.2945, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.906359  [66956/80000]
# Comparison: tensor(0.3137, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.980808  [67716/80000]
# Comparison: tensor(0.2543, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.821501  [68476/80000]
# Comparison: tensor(0.2730, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.895640  [69236/80000]
# Comparison: tensor(0.2963, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.903095  [69996/80000]
# Comparison: tensor(0.2730, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.925462  [70756/80000]
# Comparison: tensor(0.2773, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.952395  [71516/80000]
# Comparison: tensor(0.2511, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.998836  [72276/80000]
# Comparison: tensor(0.2505, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.917691  [73036/80000]
# Comparison: tensor(0.2941, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937225  [73796/80000]
# Comparison: tensor(0.2824, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.916606  [74556/80000]
# Comparison: tensor(0.2684, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.837127  [75316/80000]
# Comparison: tensor(0.3031, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.814823  [76076/80000]
# Comparison: tensor(0.3060, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.925613  [76836/80000]
# Comparison: tensor(0.2590, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.809890  [77596/80000]
# Comparison: tensor(0.3204, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.901454  [78356/80000]
# Comparison: tensor(0.3063, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.800801  [79116/80000]
# Comparison: tensor(0.3142, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.956787  [79876/80000]
# Comparison: tensor(0.2224, device='cuda:0', grad_fn=<MeanBackward0>)
# Val loss: 0.933044
#
# Epoch 2
# -------------------------------
# loss: 0.878866  [   76/80000]
# Comparison: tensor(0.3024, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954717  [  836/80000]
# Comparison: tensor(0.2941, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.986662  [ 1596/80000]
# Comparison: tensor(0.2382, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.975549  [ 2356/80000]
# Comparison: tensor(0.2669, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.860479  [ 3116/80000]
# Comparison: tensor(0.2588, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.972286  [ 3876/80000]
# Comparison: tensor(0.2313, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.935885  [ 4636/80000]
# Comparison: tensor(0.2572, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.858880  [ 5396/80000]
# Comparison: tensor(0.2913, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.885102  [ 6156/80000]
# Comparison: tensor(0.2839, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924908  [ 6916/80000]
# Comparison: tensor(0.2600, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.922396  [ 7676/80000]
# Comparison: tensor(0.2896, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.883540  [ 8436/80000]
# Comparison: tensor(0.2707, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.959976  [ 9196/80000]
# Comparison: tensor(0.2488, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.826265  [ 9956/80000]
# Comparison: tensor(0.3185, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.898320  [10716/80000]
# Comparison: tensor(0.2840, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.931161  [11476/80000]
# Comparison: tensor(0.2583, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.907976  [12236/80000]
# Comparison: tensor(0.2633, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.878804  [12996/80000]
# Comparison: tensor(0.3038, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.864114  [13756/80000]
# Comparison: tensor(0.3347, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.963169  [14516/80000]
# Comparison: tensor(0.2515, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.941260  [15276/80000]
# Comparison: tensor(0.2648, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.035039  [16036/80000]
# Comparison: tensor(0.2030, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.901086  [16796/80000]
# Comparison: tensor(0.2946, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978017  [17556/80000]
# Comparison: tensor(0.2330, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.946345  [18316/80000]
# Comparison: tensor(0.2476, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.991903  [19076/80000]
# Comparison: tensor(0.2589, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.003406  [19836/80000]
# Comparison: tensor(0.2131, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950810  [20596/80000]
# Comparison: tensor(0.2315, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914071  [21356/80000]
# Comparison: tensor(0.2613, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914136  [22116/80000]
# Comparison: tensor(0.3038, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978199  [22876/80000]
# Comparison: tensor(0.2685, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.988884  [23636/80000]
# Comparison: tensor(0.2404, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924421  [24396/80000]
# Comparison: tensor(0.2941, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.048767  [25156/80000]
# Comparison: tensor(0.2099, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.988501  [25916/80000]
# Comparison: tensor(0.2146, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.890724  [26676/80000]
# Comparison: tensor(0.2938, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.932921  [27436/80000]
# Comparison: tensor(0.2654, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.985211  [28196/80000]
# Comparison: tensor(0.2565, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.860567  [28956/80000]
# Comparison: tensor(0.2908, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.012307  [29716/80000]
# Comparison: tensor(0.2411, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.948307  [30476/80000]
# Comparison: tensor(0.2725, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900275  [31236/80000]
# Comparison: tensor(0.3209, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954030  [31996/80000]
# Comparison: tensor(0.2535, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929284  [32756/80000]
# Comparison: tensor(0.3130, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920265  [33516/80000]
# Comparison: tensor(0.2647, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.810500  [34276/80000]
# Comparison: tensor(0.3272, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.951659  [35036/80000]
# Comparison: tensor(0.2605, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.925303  [35796/80000]
# Comparison: tensor(0.2331, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.880638  [36556/80000]
# Comparison: tensor(0.2783, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.933690  [37316/80000]
# Comparison: tensor(0.2865, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912182  [38076/80000]
# Comparison: tensor(0.2707, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.886898  [38836/80000]
# Comparison: tensor(0.3029, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.961547  [39596/80000]
# Comparison: tensor(0.2493, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.857395  [40356/80000]
# Comparison: tensor(0.3431, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.941368  [41116/80000]
# Comparison: tensor(0.2660, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.865426  [41876/80000]
# Comparison: tensor(0.2840, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.887528  [42636/80000]
# Comparison: tensor(0.3044, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.976959  [43396/80000]
# Comparison: tensor(0.2430, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.891916  [44156/80000]
# Comparison: tensor(0.3192, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.916401  [44916/80000]
# Comparison: tensor(0.2985, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.015455  [45676/80000]
# Comparison: tensor(0.2130, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.908867  [46436/80000]
# Comparison: tensor(0.3193, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.886131  [47196/80000]
# Comparison: tensor(0.2654, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914353  [47956/80000]
# Comparison: tensor(0.3084, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.889177  [48716/80000]
# Comparison: tensor(0.2750, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.972412  [49476/80000]
# Comparison: tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.830020  [50236/80000]
# Comparison: tensor(0.3163, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.869405  [50996/80000]
# Comparison: tensor(0.3275, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924202  [51756/80000]
# Comparison: tensor(0.2566, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.875167  [52516/80000]
# Comparison: tensor(0.3067, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912109  [53276/80000]
# Comparison: tensor(0.2957, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.967627  [54036/80000]
# Comparison: tensor(0.2577, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.908067  [54796/80000]
# Comparison: tensor(0.2680, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.998071  [55556/80000]
# Comparison: tensor(0.2464, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.907974  [56316/80000]
# Comparison: tensor(0.2704, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.994682  [57076/80000]
# Comparison: tensor(0.2467, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.051980  [57836/80000]
# Comparison: tensor(0.2087, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.895261  [58596/80000]
# Comparison: tensor(0.2656, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.966231  [59356/80000]
# Comparison: tensor(0.2789, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.918322  [60116/80000]
# Comparison: tensor(0.2913, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978575  [60876/80000]
# Comparison: tensor(0.2491, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.936047  [61636/80000]
# Comparison: tensor(0.2481, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954659  [62396/80000]
# Comparison: tensor(0.2631, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.926235  [63156/80000]
# Comparison: tensor(0.2653, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.949763  [63916/80000]
# Comparison: tensor(0.2439, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.986659  [64676/80000]
# Comparison: tensor(0.2235, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.830363  [65436/80000]
# Comparison: tensor(0.3283, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.961748  [66196/80000]
# Comparison: tensor(0.2838, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.904367  [66956/80000]
# Comparison: tensor(0.3175, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978931  [67716/80000]
# Comparison: tensor(0.2563, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.818721  [68476/80000]
# Comparison: tensor(0.2680, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.894838  [69236/80000]
# Comparison: tensor(0.2923, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900906  [69996/80000]
# Comparison: tensor(0.2732, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.923227  [70756/80000]
# Comparison: tensor(0.2731, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950443  [71516/80000]
# Comparison: tensor(0.2525, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.996824  [72276/80000]
# Comparison: tensor(0.2522, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.916384  [73036/80000]
# Comparison: tensor(0.2978, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.936435  [73796/80000]
# Comparison: tensor(0.2804, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.915263  [74556/80000]
# Comparison: tensor(0.2699, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.836228  [75316/80000]
# Comparison: tensor(0.3033, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.812729  [76076/80000]
# Comparison: tensor(0.3124, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924719  [76836/80000]
# Comparison: tensor(0.2658, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.807858  [77596/80000]
# Comparison: tensor(0.3204, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900045  [78356/80000]
# Comparison: tensor(0.3133, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.798181  [79116/80000]
# Comparison: tensor(0.3210, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.955044  [79876/80000]
# Comparison: tensor(0.2190, device='cuda:0', grad_fn=<MeanBackward0>)
# Val loss: 0.932103
#
# Epoch 3
# -------------------------------
# loss: 0.878794  [   76/80000]
# Comparison: tensor(0.3100, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953721  [  836/80000]
# Comparison: tensor(0.2900, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.984896  [ 1596/80000]
# Comparison: tensor(0.2367, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.976099  [ 2356/80000]
# Comparison: tensor(0.2610, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.859701  [ 3116/80000]
# Comparison: tensor(0.2538, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.971483  [ 3876/80000]
# Comparison: tensor(0.2310, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.934388  [ 4636/80000]
# Comparison: tensor(0.2609, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.858441  [ 5396/80000]
# Comparison: tensor(0.2971, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.883074  [ 6156/80000]
# Comparison: tensor(0.2831, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924390  [ 6916/80000]
# Comparison: tensor(0.2578, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920958  [ 7676/80000]
# Comparison: tensor(0.2826, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.882222  [ 8436/80000]
# Comparison: tensor(0.2672, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.957904  [ 9196/80000]
# Comparison: tensor(0.2531, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.826343  [ 9956/80000]
# Comparison: tensor(0.3252, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.896565  [10716/80000]
# Comparison: tensor(0.2832, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929952  [11476/80000]
# Comparison: tensor(0.2564, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.906552  [12236/80000]
# Comparison: tensor(0.2565, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.876810  [12996/80000]
# Comparison: tensor(0.3063, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.861536  [13756/80000]
# Comparison: tensor(0.3377, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.961774  [14516/80000]
# Comparison: tensor(0.2563, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.940036  [15276/80000]
# Comparison: tensor(0.2591, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.034597  [16036/80000]
# Comparison: tensor(0.2007, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900471  [16796/80000]
# Comparison: tensor(0.2987, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.977846  [17556/80000]
# Comparison: tensor(0.2325, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.945567  [18316/80000]
# Comparison: tensor(0.2511, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.991502  [19076/80000]
# Comparison: tensor(0.2573, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.003912  [19836/80000]
# Comparison: tensor(0.2164, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.949376  [20596/80000]
# Comparison: tensor(0.2316, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912739  [21356/80000]
# Comparison: tensor(0.2669, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914461  [22116/80000]
# Comparison: tensor(0.3057, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978393  [22876/80000]
# Comparison: tensor(0.2688, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.987682  [23636/80000]
# Comparison: tensor(0.2449, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.923332  [24396/80000]
# Comparison: tensor(0.2964, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.047360  [25156/80000]
# Comparison: tensor(0.2134, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.988155  [25916/80000]
# Comparison: tensor(0.2162, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.889619  [26676/80000]
# Comparison: tensor(0.2900, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.932207  [27436/80000]
# Comparison: tensor(0.2697, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.984220  [28196/80000]
# Comparison: tensor(0.2605, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.860093  [28956/80000]
# Comparison: tensor(0.2873, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.012259  [29716/80000]
# Comparison: tensor(0.2382, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.947905  [30476/80000]
# Comparison: tensor(0.2732, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.899787  [31236/80000]
# Comparison: tensor(0.3222, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953619  [31996/80000]
# Comparison: tensor(0.2560, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929646  [32756/80000]
# Comparison: tensor(0.3106, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920104  [33516/80000]
# Comparison: tensor(0.2639, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.808899  [34276/80000]
# Comparison: tensor(0.3253, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950402  [35036/80000]
# Comparison: tensor(0.2546, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924476  [35796/80000]
# Comparison: tensor(0.2377, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.879868  [36556/80000]
# Comparison: tensor(0.2813, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.933194  [37316/80000]
# Comparison: tensor(0.2833, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.910718  [38076/80000]
# Comparison: tensor(0.2706, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.886396  [38836/80000]
# Comparison: tensor(0.3029, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.962289  [39596/80000]
# Comparison: tensor(0.2451, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.857966  [40356/80000]
# Comparison: tensor(0.3379, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.941087  [41116/80000]
# Comparison: tensor(0.2724, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.864536  [41876/80000]
# Comparison: tensor(0.2858, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.886201  [42636/80000]
# Comparison: tensor(0.3037, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.976014  [43396/80000]
# Comparison: tensor(0.2429, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.890301  [44156/80000]
# Comparison: tensor(0.3132, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914548  [44916/80000]
# Comparison: tensor(0.2990, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.015430  [45676/80000]
# Comparison: tensor(0.2173, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.907557  [46436/80000]
# Comparison: tensor(0.3221, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.883824  [47196/80000]
# Comparison: tensor(0.2640, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912625  [47956/80000]
# Comparison: tensor(0.3043, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.889117  [48716/80000]
# Comparison: tensor(0.2733, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.971828  [49476/80000]
# Comparison: tensor(0.2253, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.828114  [50236/80000]
# Comparison: tensor(0.3097, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.868393  [50996/80000]
# Comparison: tensor(0.3265, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924287  [51756/80000]
# Comparison: tensor(0.2559, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.874748  [52516/80000]
# Comparison: tensor(0.3049, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.910501  [53276/80000]
# Comparison: tensor(0.2956, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.966717  [54036/80000]
# Comparison: tensor(0.2549, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.908912  [54796/80000]
# Comparison: tensor(0.2615, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.997881  [55556/80000]
# Comparison: tensor(0.2482, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.906007  [56316/80000]
# Comparison: tensor(0.2748, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.993853  [57076/80000]
# Comparison: tensor(0.2468, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.050750  [57836/80000]
# Comparison: tensor(0.2023, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.894097  [58596/80000]
# Comparison: tensor(0.2702, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.966444  [59356/80000]
# Comparison: tensor(0.2816, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.919022  [60116/80000]
# Comparison: tensor(0.2844, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.979137  [60876/80000]
# Comparison: tensor(0.2470, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.935826  [61636/80000]
# Comparison: tensor(0.2507, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953943  [62396/80000]
# Comparison: tensor(0.2666, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.925977  [63156/80000]
# Comparison: tensor(0.2689, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.948808  [63916/80000]
# Comparison: tensor(0.2391, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.985942  [64676/80000]
# Comparison: tensor(0.2183, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.828781  [65436/80000]
# Comparison: tensor(0.3273, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.961479  [66196/80000]
# Comparison: tensor(0.2843, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.903341  [66956/80000]
# Comparison: tensor(0.3186, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978771  [67716/80000]
# Comparison: tensor(0.2552, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.817811  [68476/80000]
# Comparison: tensor(0.2671, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.893677  [69236/80000]
# Comparison: tensor(0.2934, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900506  [69996/80000]
# Comparison: tensor(0.2782, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.923199  [70756/80000]
# Comparison: tensor(0.2752, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950144  [71516/80000]
# Comparison: tensor(0.2478, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.995329  [72276/80000]
# Comparison: tensor(0.2470, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.916906  [73036/80000]
# Comparison: tensor(0.2936, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.936012  [73796/80000]
# Comparison: tensor(0.2806, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.915512  [74556/80000]
# Comparison: tensor(0.2709, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.835855  [75316/80000]
# Comparison: tensor(0.3107, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.812171  [76076/80000]
# Comparison: tensor(0.3111, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924504  [76836/80000]
# Comparison: tensor(0.2587, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.807433  [77596/80000]
# Comparison: tensor(0.3222, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.899366  [78356/80000]
# Comparison: tensor(0.3112, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.797616  [79116/80000]
# Comparison: tensor(0.3147, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.955206  [79876/80000]
# Comparison: tensor(0.2259, device='cuda:0', grad_fn=<MeanBackward0>)
# Val loss: 0.931930
#
# Epoch 4
# -------------------------------
# loss: 0.877795  [   76/80000]
# Comparison: tensor(0.3050, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953670  [  836/80000]
# Comparison: tensor(0.2931, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.984588  [ 1596/80000]
# Comparison: tensor(0.2361, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.974577  [ 2356/80000]
# Comparison: tensor(0.2628, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.859752  [ 3116/80000]
# Comparison: tensor(0.2614, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.972103  [ 3876/80000]
# Comparison: tensor(0.2277, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.934099  [ 4636/80000]
# Comparison: tensor(0.2587, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.856923  [ 5396/80000]
# Comparison: tensor(0.2890, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.884186  [ 6156/80000]
# Comparison: tensor(0.2841, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924174  [ 6916/80000]
# Comparison: tensor(0.2588, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.920495  [ 7676/80000]
# Comparison: tensor(0.2900, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.881601  [ 8436/80000]
# Comparison: tensor(0.2693, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.958080  [ 9196/80000]
# Comparison: tensor(0.2500, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.824966  [ 9956/80000]
# Comparison: tensor(0.3260, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.896029  [10716/80000]
# Comparison: tensor(0.2844, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929619  [11476/80000]
# Comparison: tensor(0.2584, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.906631  [12236/80000]
# Comparison: tensor(0.2585, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.876489  [12996/80000]
# Comparison: tensor(0.3072, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.862145  [13756/80000]
# Comparison: tensor(0.3374, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.960736  [14516/80000]
# Comparison: tensor(0.2546, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.939428  [15276/80000]
# Comparison: tensor(0.2594, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.033243  [16036/80000]
# Comparison: tensor(0.2016, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.899649  [16796/80000]
# Comparison: tensor(0.2953, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.976799  [17556/80000]
# Comparison: tensor(0.2366, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.944652  [18316/80000]
# Comparison: tensor(0.2484, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.991253  [19076/80000]
# Comparison: tensor(0.2634, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.003502  [19836/80000]
# Comparison: tensor(0.2140, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.949283  [20596/80000]
# Comparison: tensor(0.2302, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912621  [21356/80000]
# Comparison: tensor(0.2603, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914212  [22116/80000]
# Comparison: tensor(0.2988, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.977388  [22876/80000]
# Comparison: tensor(0.2689, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.988422  [23636/80000]
# Comparison: tensor(0.2446, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.922347  [24396/80000]
# Comparison: tensor(0.2902, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.047339  [25156/80000]
# Comparison: tensor(0.2011, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.987057  [25916/80000]
# Comparison: tensor(0.2181, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.889165  [26676/80000]
# Comparison: tensor(0.2925, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.931291  [27436/80000]
# Comparison: tensor(0.2668, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.983847  [28196/80000]
# Comparison: tensor(0.2595, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.859678  [28956/80000]
# Comparison: tensor(0.2859, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.010865  [29716/80000]
# Comparison: tensor(0.2404, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.948942  [30476/80000]
# Comparison: tensor(0.2746, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.899249  [31236/80000]
# Comparison: tensor(0.3177, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.953475  [31996/80000]
# Comparison: tensor(0.2537, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.929945  [32756/80000]
# Comparison: tensor(0.3124, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.919088  [33516/80000]
# Comparison: tensor(0.2677, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.809351  [34276/80000]
# Comparison: tensor(0.3226, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950354  [35036/80000]
# Comparison: tensor(0.2542, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.923946  [35796/80000]
# Comparison: tensor(0.2347, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.879934  [36556/80000]
# Comparison: tensor(0.2803, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.932382  [37316/80000]
# Comparison: tensor(0.2859, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.911033  [38076/80000]
# Comparison: tensor(0.2649, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.885584  [38836/80000]
# Comparison: tensor(0.3035, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.961730  [39596/80000]
# Comparison: tensor(0.2486, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.856760  [40356/80000]
# Comparison: tensor(0.3352, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.940454  [41116/80000]
# Comparison: tensor(0.2759, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.863269  [41876/80000]
# Comparison: tensor(0.2855, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.885683  [42636/80000]
# Comparison: tensor(0.3030, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.975335  [43396/80000]
# Comparison: tensor(0.2455, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.890493  [44156/80000]
# Comparison: tensor(0.3210, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.914364  [44916/80000]
# Comparison: tensor(0.2962, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.014281  [45676/80000]
# Comparison: tensor(0.2129, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.908151  [46436/80000]
# Comparison: tensor(0.3170, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.885237  [47196/80000]
# Comparison: tensor(0.2634, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.913387  [47956/80000]
# Comparison: tensor(0.3067, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.888542  [48716/80000]
# Comparison: tensor(0.2714, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.971355  [49476/80000]
# Comparison: tensor(0.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.829027  [50236/80000]
# Comparison: tensor(0.3139, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.868169  [50996/80000]
# Comparison: tensor(0.3248, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.922408  [51756/80000]
# Comparison: tensor(0.2539, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.873622  [52516/80000]
# Comparison: tensor(0.3050, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.912355  [53276/80000]
# Comparison: tensor(0.3007, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.966069  [54036/80000]
# Comparison: tensor(0.2598, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.907692  [54796/80000]
# Comparison: tensor(0.2640, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.997542  [55556/80000]
# Comparison: tensor(0.2450, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.905349  [56316/80000]
# Comparison: tensor(0.2747, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.993889  [57076/80000]
# Comparison: tensor(0.2452, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 1.050444  [57836/80000]
# Comparison: tensor(0.2056, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.894269  [58596/80000]
# Comparison: tensor(0.2632, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.965771  [59356/80000]
# Comparison: tensor(0.2813, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.918435  [60116/80000]
# Comparison: tensor(0.2942, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978245  [60876/80000]
# Comparison: tensor(0.2569, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.936151  [61636/80000]
# Comparison: tensor(0.2492, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954107  [62396/80000]
# Comparison: tensor(0.2586, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.925547  [63156/80000]
# Comparison: tensor(0.2634, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.948696  [63916/80000]
# Comparison: tensor(0.2323, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.985520  [64676/80000]
# Comparison: tensor(0.2194, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.829611  [65436/80000]
# Comparison: tensor(0.3301, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.960776  [66196/80000]
# Comparison: tensor(0.2898, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.904837  [66956/80000]
# Comparison: tensor(0.3128, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.978563  [67716/80000]
# Comparison: tensor(0.2576, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.818351  [68476/80000]
# Comparison: tensor(0.2685, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.893385  [69236/80000]
# Comparison: tensor(0.2917, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.900316  [69996/80000]
# Comparison: tensor(0.2765, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.922447  [70756/80000]
# Comparison: tensor(0.2791, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.950695  [71516/80000]
# Comparison: tensor(0.2551, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.994910  [72276/80000]
# Comparison: tensor(0.2438, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.915719  [73036/80000]
# Comparison: tensor(0.2943, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.937127  [73796/80000]
# Comparison: tensor(0.2880, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.916579  [74556/80000]
# Comparison: tensor(0.2712, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.835977  [75316/80000]
# Comparison: tensor(0.3065, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.812388  [76076/80000]
# Comparison: tensor(0.3071, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.924194  [76836/80000]
# Comparison: tensor(0.2632, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.808380  [77596/80000]
# Comparison: tensor(0.3202, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.899878  [78356/80000]
# Comparison: tensor(0.3061, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.797452  [79116/80000]
# Comparison: tensor(0.3183, device='cuda:0', grad_fn=<MeanBackward0>)
# loss: 0.954874  [79876/80000]
# Comparison: tensor(0.2202, device='cuda:0', grad_fn=<MeanBackward0>)
